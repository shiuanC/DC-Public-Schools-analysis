# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/DS1final"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DS1final

# %%
import pandas as pd
import numpy as np
import random
import re
import string

# %%
# !ls school_spending
# Out:
# AK_1819_final_January_28th_22.xlsx  MS_1819_final_January_28th_22.xlsx
# AL_1819_final_January_28th_22.xlsx  MT_1819_final_January_28th_22.xlsx
# AR_1819_final_January_28th_22.xlsx  NC_1819_final_January_28th_22.xlsx
# AZ_1819_final_January_28th_22.xlsx  ND_1819_final_January_28th_22.xlsx
# CA_1819_final_January_28th_22.xlsx  NE_1819_final_January_28th_22.xlsx
# CO_1819_final_January_28th_22.xlsx  NH_1819_final_January_28th_22.xlsx
# CT_1819_final_January_28th_22.xlsx  NJ_1819_update_Sep2022.xlsx
# DC_1819_final_January_28th_22.xlsx  NM_1819_final_January_28th_22.xlsx
# DE_1819_final_January_28th_22.xlsx  NV_1819_final_January_28th_22.xlsx
# FL_1819_final_January_28th_22.xlsx  NY_1819_final_January_28th_22.xlsx
# GA_1819_final_January_28th_22.xlsx  OH_1819_final_January_28th_22.xlsx
# HI_1819_final_January_28th_22.xlsx  OK_1819_final_January_28th_22.xlsx
# IA_1819_final_January_28th_22.xlsx  OR_1819_final_January_28th_22.xlsx
# ...

# %%
df_jan=pd.read_excel("Dataset/ELAB_Educ_data/DC_1819_final_January_28th_22.xlsx")
df_sep=pd.read_excel("Dataset/ELAB_Educ_data/DC_1819_final_September_23rd_22.xlsx")
df_sep.head()
# Out:
#   state       year  distid_stateassigned  schoolid_stateassigned  \
# 0    DC  2018-2019                   178                     233
# 1    DC  2018-2019                   155                     217
# 2    DC  2018-2019                   155                    1100
# 3    DC  2018-2019                   103                     140
# 4    DC  2018-2019                   103                    3072
#
#                               distname  \
# 0            Academy of Hope Adult PCS
# 1  Achievement Preparatory Academy PCS
# 2  Achievement Preparatory Academy PCS
# 3         AppleTree Early Learning PCS
# 4         AppleTree Early Learning PCS
#
#                                           schoolname  ncesdistid_admin  \
# 0                          Academy of Hope Adult PCS               NaN
# 1  Achievement Preparatory Academy PCS - Wahler P...         1100072.0
# 2  Achievement Preparatory Academy PCS - Wahler P...         1100072.0
# ...

# %%
df = df_jan.merge(df_sep, on='schoolid_stateassigned')

# %%
df.to_csv('/content/drive/MyDrive/DS1final/Dataset/final_data/nces_finana_join.csv')

# %%
dc_df.isna().sum()
# Out:
# state                          0
# year                           0
# distid_stateassigned           0
# schoolid_stateassigned         0
# distname                       0
# schoolname                     0
# ncesdistid_admin               8
# ncesdistid_geo                 8
# census_id                    126
# ncesid                        10
# ncesenroll                    21
# gradespan                     12
# level                         12
# enroll_raw_DC                  0
# enrollmetric                   0
# pp_stloc_raw_DC                0
# pp_fed_raw_DC                  0
# pp_total_raw_DC                0
# pp_site_stloc_raw_DC          43
# pp_site_fed_raw_DC            43
# pp_site_raw_DC                43
# pp_centshare_stloc_raw_DC     43
# pp_centshare_fed_raw_DC       43
# pp_centshare_raw_DC           43
# schoolstloc_raw_DC             0
# schoolfed_raw_DC               0
# schooltot_raw_DC               0
# pp_total_norm_NERDS           47
# ...
