# %%
import glob
import pandas as pd
import numpy as np

# %%
dc_test_score4 = pd.read_csv("DPCsv202211063914.csv")
print(dc_test_score4.shape)
dc_test_score4.head()
#dc_crim_2020.shape
# Out:
# (22, 13)
#                            Subject  Grade  Year      MN  MN_SE  SigDiff  \
# 0  Mathematics (scale range 0–500)      4  2022  224.08  1.506    -2.48
# 1  Mathematics (scale range 0–500)      4  2019  235.28  0.749     0.48
# 2  Mathematics (scale range 0–500)      4  2017  230.80  0.853    -0.72
# 3  Mathematics (scale range 0–500)      4  2015  232.21  0.853    -1.77
# 4  Mathematics (scale range 0–500)      4  2013  228.61  0.783    -6.34
#
#   SigSymbol     AB  AB_SE     AP  AP_SE    AD  AD_SE
# 0         ♦  58.04  1.926  26.70  1.698  7.40  0.914
# 1         ♦  72.80  1.426  35.60  1.207  9.69  0.756
# 2         ♦  66.69  1.307  31.46  1.206  9.08  0.800
# 3         ♦  68.36  1.526  33.01  1.150  9.09  0.826
# 4         ▼  64.48  1.427  29.72  1.068  7.92  0.933

# %%
SAT_scores_21=pd.read_csv("SchoolYear2020-2021-SATScores.csv")
SAT_scores_19=pd.read_excel("School Year 2018-2019 SAT Scores.xlsx")
print(SAT_scores_22.shape)
SAT_scores_21
SAT_scores_19
# Out:
# (27, 6)
#      Unnamed: 0                                         Unnamed: 1  \
# 0            ps                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4   School Code                                        School Name
# 5           402                               Benjamin Banneker HS
# 6           436          Ron Brown College Preparatory High School
# 7           442                         Columbia Heights EC (CHEC)
# 8           450                                       Anacostia HS
# 9           452                                          Ballou HS
# 10          454                                         Cardozo EC
# 11          455                                        Coolidge HS
# 12          456                                     Roosevelt STAY
# 13          457                                         Eastern HS
# 14          458                             McKinley Technology HS
# 15          459                                       Roosevelt HS
# 16          462                                        Ballou STAY
# 17          463                                  Woodrow Wilson HS
# 18          464                                   Woodson, H.D. HS
# 19          466                            School Without Walls HS
# 20          467                                          Dunbar HS
# 21          471                  Duke Ellington School of the Arts
# 22          474                         Washington Metropolitan HS
# 23          478  Phelps Architecture, Construction and Engineer...
# 24          884                                   Luke C. Moore HS
# 25         DCPS                                           District
#
#                Unnamed: 2                                  Unnamed: 3  \
# 0                     NaN                                         NaN
# 1                     NaN                                         NaN
# 2                     NaN                                         NaN
# 3                     NaN                                         NaN
# 4   Number of Test-takers  Evidence-Based Reading and Writing Average
# 5                     206                                  557.281555
# 6                      57                                  429.122803
# 7                     371                                  444.447449
# 8                     101                                   381.28714
# 9                     240                                  396.666656
# 10                    178                                  392.359558
# 11                    126                                  401.746033
# 12                     34                                  388.823517
# 13                    296                                         415
# 14                    270                                  504.814819
# 15                    199                                  422.060303
# 16                     25                                  401.600006
# 17                    658                                  545.957458
# 18                    230                                  403.478271
# 19                    252                                  646.507935
# 20                    214                                  402.663544
# 21                    226                                  501.061951
# 22                     16                                       357.5
# 23                    113                                  436.106201
# 24                     21                                  403.809509
# 25                   3833                                  470.273926
#
#       Unnamed: 4 DATA AS OF: 12/3/2019
# 0            NaN                   NaN
# 1            NaN                   NaN
# 2            NaN                   NaN
# 3            NaN                   NaN
# 4   Math Average         Total Average
# 5     553.689331           1110.970825
# 6     410.175446            839.298218
# 7     428.840973            873.288391
# 8     374.059418            755.346558
# 9     381.833344                 778.5
# 10    394.044952             786.40448
# 11    387.460327             789.20636
# 12    368.235291            757.058838
# 13    398.344604            813.344604
# 14    500.888885           1005.703674
# 15    401.909546            823.969849
# 16           376            777.599976
# 17     528.98175           1074.939209
# 18    380.478271            783.956543
# 19    630.753967           1277.261963
# 20    383.831787              786.4953
# 21    452.345123            953.407104
# 22       321.875               679.375
# 23    414.247803            850.354004
# 24    383.809509            787.619019
# 25    453.662933             923.93689

# %%
SAT_clean21 = SAT_scores_21.tail(-5)
#SAT_clean21
SAT_clean19 = SAT_scores_19.tail(-5)
SAT_clean19
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 5         402                               Benjamin Banneker HS        206
# 6         436          Ron Brown College Preparatory High School         57
# 7         442                         Columbia Heights EC (CHEC)        371
# 8         450                                       Anacostia HS        101
# 9         452                                          Ballou HS        240
# 10        454                                         Cardozo EC        178
# 11        455                                        Coolidge HS        126
# 12        456                                     Roosevelt STAY         34
# 13        457                                         Eastern HS        296
# 14        458                             McKinley Technology HS        270
# 15        459                                       Roosevelt HS        199
# 16        462                                        Ballou STAY         25
# 17        463                                  Woodrow Wilson HS        658
# 18        464                                   Woodson, H.D. HS        230
# 19        466                            School Without Walls HS        252
# 20        467                                          Dunbar HS        214
# 21        471                  Duke Ellington School of the Arts        226
# 22        474                         Washington Metropolitan HS         16
# 23        478  Phelps Architecture, Construction and Engineer...        113
# 24        884                                   Luke C. Moore HS         21
# 25       DCPS                                           District       3833
#
#     Unnamed: 3  Unnamed: 4 DATA AS OF: 12/3/2019
# 5   557.281555  553.689331           1110.970825
# 6   429.122803  410.175446            839.298218
# 7   444.447449  428.840973            873.288391
# 8    381.28714  374.059418            755.346558
# 9   396.666656  381.833344                 778.5
# 10  392.359558  394.044952             786.40448
# 11  401.746033  387.460327             789.20636
# 12  388.823517  368.235291            757.058838
# 13         415  398.344604            813.344604
# 14  504.814819  500.888885           1005.703674
# 15  422.060303  401.909546            823.969849
# 16  401.600006         376            777.599976
# 17  545.957458   528.98175           1074.939209
# 18  403.478271  380.478271            783.956543
# 19  646.507935  630.753967           1277.261963
# 20  402.663544  383.831787              786.4953
# 21  501.061951  452.345123            953.407104
# 22       357.5     321.875               679.375
# 23  436.106201  414.247803            850.354004
# 24  403.809509  383.809509            787.619019
# 25  470.273926  453.662933             923.93689

# %%
#CREARE COLUMN THAT HAS YEAR

# %%
SAT_clean21 = SAT_clean21.rename(columns={'Unnamed: 0': 'CODE', 'Unnamed: 1': 'SCHOOL', 'Unnamed: 2': 'TEST_TAKERS', 'Unnamed: 3': 'AVG_READING_SCORE','Unnamed: 4': 'AVG_MATH_SCORE','DATA AS OF: 11/23/2021':'AVG_TOTAL'})
SAT_clean21.columns = [*SAT_clean21.columns[:-1], 'AVG_TOTAL']

SAT_clean19 = SAT_clean19.rename(columns={'Unnamed: 0': 'CODE', 'Unnamed: 1': 'SCHOOL', 'Unnamed: 2': 'TEST_TAKERS', 'Unnamed: 3': 'AVG_READING_SCORE','Unnamed: 4': 'AVG_MATH_SCORE','DATA AS OF: 12/3/2019':'AVG_TOTAL'})

#SAT_clean21.head()
SAT_clean19.head()
# Out:
#   CODE                                     SCHOOL TEST_TAKERS  \
# 5  402                       Benjamin Banneker HS         206
# 6  436  Ron Brown College Preparatory High School          57
# 7  442                 Columbia Heights EC (CHEC)         371
# 8  450                               Anacostia HS         101
# 9  452                                  Ballou HS         240
#
#    AVG_READING_SCORE AVG_MATH_SCORE    AVG_TOTAL
# 5                551     553.689331  1110.970825
# 6                435     410.175446   839.298218
# 7                425     428.840973   873.288391
# 8                416     374.059418   755.346558
# 9                379     381.833344        778.5

# %%
SAT_clean19['AVG_READING_SCORE'] = df['AVG_READING_SCORE'].astype(int)
SAT_clean19['AVG_MATH_SCORE'] = df['AVG_MATH_SCORE'].astype(int) #WHY ISNT THIS WORKING
#SAT_clean19.columns = [*SAT_clean19.columns[:-1].astype(int)]
#SAT_clean19['AVG_TOTAL'] = df['AVG_TOTAL'].astype(int) #WHY ISNT THIS WORKING
SAT_clean19.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/PPOL564/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/anaconda3/envs/PPOL564/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/PPOL564/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AVG_MATH_SCORE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [113], in <cell line: 2>()
#       1 SAT_clean19['AVG_READING_SCORE'] = df['AVG_READING_SCORE'].astype(int)
# ----> 2 SAT_clean19['AVG_MATH_SCORE'] = df['AVG_MATH_SCORE'].astype(int) #WHY ISNT THIS WORKING
#       3 #SAT_clean19.columns = [*SAT_clean19.columns[:-1].astype(int)]
#       4 #SAT_clean19['AVG_TOTAL'] = df['AVG_TOTAL'].astype(int) #WHY ISNT THIS WORKING
#       5 SAT_clean19.head()
#
# File /opt/anaconda3/envs/PPOL564/lib/python3.10/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File /opt/anaconda3/envs/PPOL564/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'AVG_MATH_SCORE'

# %%
import plotnine
from plotnine import *

(ggplot(SAT_clean21, aes(x = 'SCHOOL', y = 'AVG_READING_SCORE')) +
geom_bar(stat = 'identity', position = 'dodge') +
theme(axis_text_x= element_text(angle = 90)))
# Out:
# <ggplot: (8763546910943)>

# %%
(ggplot(SAT_clean21, aes(x = 'SCHOOL', y = 'AVG_MATH_SCORE')) +
geom_bar(stat = 'identity', position = 'dodge') +
theme(axis_text_x= element_text(angle = 90)))
# Out:
# <ggplot: (8763549848126)>

# %%
combined_SAT_scores = pd.concat([SAT_clean21, SAT_clean19])
combined_SAT_scores
# Out:
#     CODE                                             SCHOOL TEST_TAKERS  \
# 5    402                               Benjamin Banneker HS          82
# 6    436          Ron Brown College Preparatory High School           2
# 7    442                         Columbia Heights EC (CHEC)         102
# 8    450                                       Anacostia HS          15
# 9    452                                          Ballou HS          10
# 10   454                                         Cardozo EC          14
# 11   455                                        Coolidge HS          22
# 12   456                                     Roosevelt STAY           2
# 13   457                                         Eastern HS          28
# 14   458                             McKinley Technology HS          71
# 15   459                                       Roosevelt HS          38
# 16   462                                        Ballou STAY           4
# 17   463                                  Woodrow Wilson HS         218
# 18   464                                    Woodson H.D. HS          14
# 19   466                            School Without Walls HS         157
# 20   467                                          Dunbar HS         157
# 21   471                  Duke Ellington School of the Arts          59
# 22   478  Phelps Architecture Construction and Engineeri...          15
# 23   861                              Youth Services Center           9
# 24   884                                   Luke C. Moore HS           5
# 25  1058       Bard High School Early College DC (Bard DC)            7
# 26  DCPS                                           District        1031
# 5    402                               Benjamin Banneker HS         206
# 6    436          Ron Brown College Preparatory High School          57
# 7    442                         Columbia Heights EC (CHEC)         371
# 8    450                                       Anacostia HS         101
# 9    452                                          Ballou HS         240
# 10   454                                         Cardozo EC         178
# 11   455                                        Coolidge HS         126
# 12   456                                     Roosevelt STAY          34
# 13   457                                         Eastern HS         296
# 14   458                             McKinley Technology HS         270
# 15   459                                       Roosevelt HS         199
# 16   462                                        Ballou STAY          25
# 17   463                                  Woodrow Wilson HS         658
# 18   464                                   Woodson, H.D. HS         230
# 19   466                            School Without Walls HS         252
# 20   467                                          Dunbar HS         214
# 21   471                  Duke Ellington School of the Arts         226
# 22   474                         Washington Metropolitan HS          16
# 23   478  Phelps Architecture, Construction and Engineer...         113
# 24   884                                   Luke C. Moore HS          21
# 25  DCPS                                           District        3833
#
#    AVG_READING_SCORE AVG_MATH_SCORE    AVG_TOTAL
# 5                551            552         1104
# 6                435            405          840
# 7                425            419          845
# 8                416            405          822
# 9                379            383          762
# 10               384            397          781
# 11               395            381          776
# 12               360            420          780
# 13               450            416          866
# 14               504            480          985
# 15               424            404          828
# 16               435            370          805
# 17               608            587         1196
# 18               397            385          782
# 19               663            637         1300
# 20               506            479          986
# 21               536            483         1020
# 22               448            426          874
# 23               394            357          752
# 24               364            342          706
# 25               500            465          965
# 26               533            512         1045
# 5                551     553.689331  1110.970825
# 6                435     410.175446   839.298218
# 7                425     428.840973   873.288391
# 8                416     374.059418   755.346558
# 9                379     381.833344        778.5
# 10               384     394.044952    786.40448
# 11               395     387.460327    789.20636
# 12               360     368.235291   757.058838
# 13               450     398.344604   813.344604
# 14               504     500.888885  1005.703674
# 15               424     401.909546   823.969849
# 16               435            376   777.599976
# 17               608      528.98175  1074.939209
# 18               397     380.478271   783.956543
# 19               663     630.753967  1277.261963
# 20               506     383.831787     786.4953
# 21               536     452.345123   953.407104
# 22               448        321.875      679.375
# 23               394     414.247803   850.354004
# 24               364     383.809509   787.619019
# 25               500     453.662933    923.93689

# %%
#need to combine 2019 and 2021 data sets 
#plot math and reading scores with year as the grouping and fill variables
(ggplot(combined_SAT_scores, aes(x = 'SCHOOL', y = 'AVG_READING_SCORE',
                      group = 'factor(year)',
                      fill = 'factor(year)')) +
geom_bar(stat = 'identity', position = 'dodge') +
theme(axis_text_x= element_text(angle = 90)))
