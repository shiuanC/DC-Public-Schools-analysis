# %%
import glob
import pandas as pd
import numpy as np

# %%
grad_rates21=pd.read_excel("Graduation_rates2021.xlsx")
print(grad_rates21.shape)
grad_rates21
# Out:
# (230, 5)
#       Unnamed: 0         Unnamed: 1 DATA AS OF: 11/09/2021 Unnamed: 3  \
# 0            NaN                NaN                    NaN        NaN
# 1            NaN                NaN                    NaN        NaN
# 2            NaN                NaN                    NaN        NaN
# 3            NaN                NaN                    NaN        NaN
# 4    School Code        School Name               Subgroup    # Grads
# ..           ...                ...                    ...        ...
# 225         DCPS  DC Public Schools           Multi-Racial         34
# 226         DCPS  DC Public Schools             Non-binary     n < 10
# 227         DCPS  DC Public Schools       Pacific Islander     n < 10
# 228         DCPS  DC Public Schools                    SWD        259
# 229         DCPS  DC Public Schools                  White        250
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4       % Grad
# ..         ...
# 225   0.894737
# 226        NaN
# 227        NaN
# 228   0.473492
# 229   0.902527
#
# [230 rows x 5 columns]

# %%
grad_rates19=pd.read_excel("graduation_rates19.xlsx")
grad_rates19
# Out:
#       Unnamed: 0         Unnamed: 1  \
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4    School Code        School Name
# ..           ...                ...
# 201         DCPS  DC Public Schools
# 202         DCPS  DC Public Schools
# 203         DCPS  DC Public Schools
# 204         DCPS  DC Public Schools
# 205         DCPS  DC Public Schools
#
#                                  DATA AS OF: 11/6/2019 Unnamed: 3 Unnamed: 4
# 0    Note. There were 22 graduates among 105 studen...        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                                             Subgroup    # Grads     % Grad
# ..                                                 ...        ...        ...
# 201                                               Male        981    0.57842
# 202                                       Multi-Racial         28   0.777778
# 203                                   Pacific Islander     n < 10        NaN
# 204                                                SWD        271   0.437803
# 205                                              White        229   0.923387
#
# [206 rows x 5 columns]

# %%
grad_rates21 = grad_rates21.tail(-5)
grad_rates19 = grad_rates19.tail(-5)
grad_rates21
# Out:
#     Unnamed: 0            Unnamed: 1 DATA AS OF: 11/09/2021 Unnamed: 3  \
# 5          402  Benjamin Banneker HS                    All        113
# 6          402  Benjamin Banneker HS                  Asian     n < 10
# 7          402  Benjamin Banneker HS                At-Risk         33
# 8          402  Benjamin Banneker HS                  Black         85
# 9          402  Benjamin Banneker HS                     EL     n < 10
# ..         ...                   ...                    ...        ...
# 225       DCPS     DC Public Schools           Multi-Racial         34
# 226       DCPS     DC Public Schools             Non-binary     n < 10
# 227       DCPS     DC Public Schools       Pacific Islander     n < 10
# 228       DCPS     DC Public Schools                    SWD        259
# 229       DCPS     DC Public Schools                  White        250
#
#     Unnamed: 4
# 5            1
# 6          NaN
# 7            1
# 8            1
# 9          NaN
# ..         ...
# 225   0.894737
# 226        NaN
# 227        NaN
# 228   0.473492
# 229   0.902527
#
# [225 rows x 5 columns]

# %%
grad_rates_clean21 = grad_rates21.rename(columns={'Unnamed: 0': 'CODE', 'Unnamed: 1': 'SCHOOL', 'DATA AS OF: 11/09/2021': 'ETHNICITY', 'Unnamed: 3': 'N_GRADS','Unnamed: 4': 'GRAD_PERCENTAGE'})
grad_rates_clean19 = grad_rates19.rename(columns={'Unnamed: 0': 'CODE', 'Unnamed: 1': 'SCHOOL', 'DATA AS OF: 11/6/2019': 'ETHNICITY', 'Unnamed: 3': 'N_GRADS','Unnamed: 4': 'GRAD_PERCENTAGE'})

# %%
grad_rates_clean19
# Out:
#      CODE                SCHOOL         ETHNICITY N_GRADS GRAD_PERCENTAGE
# 5     402  Benjamin Banneker HS               All     108               1
# 6     402  Benjamin Banneker HS             Asian  n < 10             NaN
# 7     402  Benjamin Banneker HS           At-Risk      29               1
# 8     402  Benjamin Banneker HS             Black      78               1
# 9     402  Benjamin Banneker HS                EL  n < 10             NaN
# ..    ...                   ...               ...     ...             ...
# 201  DCPS     DC Public Schools              Male     981         0.57842
# 202  DCPS     DC Public Schools      Multi-Racial      28        0.777778
# 203  DCPS     DC Public Schools  Pacific Islander  n < 10             NaN
# 204  DCPS     DC Public Schools               SWD     271        0.437803
# 205  DCPS     DC Public Schools             White     229        0.923387
#
# [201 rows x 5 columns]

# %%
grad_rates_clean19['YEAR']= 2019
grad_rates_clean21['YEAR']=2021
grad_rates_clean21
# Out:
#      CODE                SCHOOL         ETHNICITY N_GRADS GRAD_PERCENTAGE  \
# 5     402  Benjamin Banneker HS               All     113               1
# 6     402  Benjamin Banneker HS             Asian  n < 10             NaN
# 7     402  Benjamin Banneker HS           At-Risk      33               1
# 8     402  Benjamin Banneker HS             Black      85               1
# 9     402  Benjamin Banneker HS                EL  n < 10             NaN
# ..    ...                   ...               ...     ...             ...
# 225  DCPS     DC Public Schools      Multi-Racial      34        0.894737
# 226  DCPS     DC Public Schools        Non-binary  n < 10             NaN
# 227  DCPS     DC Public Schools  Pacific Islander  n < 10             NaN
# 228  DCPS     DC Public Schools               SWD     259        0.473492
# 229  DCPS     DC Public Schools             White     250        0.902527
#
#      YEAR
# 5    2021
# 6    2021
# 7    2021
# 8    2021
# 9    2021
# ..    ...
# 225  2021
# 226  2021
# 227  2021
# 228  2021
# 229  2021
#
# [225 rows x 6 columns]

# %%
grad_rate_total21 = grad_rates_clean21[grad_rates_clean21['ETHNICITY']=="All"]
grad_rate_total19 = grad_rates_clean19[grad_rates_clean19['ETHNICITY']=="All"]

# %%
grad_rate_total21
# Out:
#      CODE                                             SCHOOL ETHNICITY  \
# 5     402                               Benjamin Banneker HS       All
# 14    436          Ron Brown College Preparatory High School       All
# 19    442                         Columbia Heights EC (CHEC)       All
# 30    450                                       Anacostia HS       All
# 36    452                                          Ballou HS       All
# 44    454                                         Cardozo EC       All
# 53    455                                        Coolidge HS       All
# 62    456                                  Roosevelt STAY HS       All
# 71    457                                         Eastern HS       All
# 81    458                             McKinley Technology HS       All
# 92    459                                       Roosevelt HS       All
# 103   462                                     Ballou STAY HS       All
# 110   463                                  Woodrow Wilson HS       All
# 122   464                                   Woodson, H.D. HS       All
# 131   465                    Tuition Grant - DCPS Non Public       All
# 140   466                            School Without Walls HS       All
# 151   467                                          Dunbar HS       All
# 161   471                  Duke Ellington School of the Arts       All
# 173   474                Washington Metropolitan High School       All
# 179   478  Phelps Architecture, Construction and Engineer...       All
# 187   950                            Inspiring Youth Program       All
# 192   861                              Youth Services Center       All
# 199   884                                   Luke C. Moore HS       All
# 208  1058        Bard High School Early College DC (Bard DC)       All
# 216  DCPS                                  DC Public Schools       All
#
#     N_GRADS GRAD_PERCENTAGE  YEAR
# 5       113               1  2021
# 14       42        0.736842  2021
# 19      178        0.801802  2021
# 30       42        0.736842  2021
# 36      131        0.696809  2021
# 44       78        0.666667  2021
# 53       69         0.71134  2021
# 62       20        0.127389  2021
# 71      116           0.725  2021
# 81      153        0.993506  2021
# 92      119        0.661111  2021
# 103  n < 10             NaN  2021
# 110     418        0.887473  2021
# 122      75        0.707547  2021
# 131      17        0.204819  2021
# 140     142         0.95302  2021
# 151     164        0.745455  2021
# 161     117        0.991525  2021
# 173  n < 10             NaN  2021
# 179      44        0.956522  2021
# 187  n < 10             NaN  2021
# 192  n < 10             NaN  2021
# 199  n < 10             NaN  2021
# 208      15               1  2021
# 216    2063        0.706023  2021

# %%
joined_grad_rate=pd.concat([grad_rates_clean19, grad_rates_clean21], axis=0)
joined_grad_rate
# Out:
#      CODE                SCHOOL         ETHNICITY N_GRADS GRAD_PERCENTAGE  \
# 5     402  Benjamin Banneker HS               All     108               1
# 6     402  Benjamin Banneker HS             Asian  n < 10             NaN
# 7     402  Benjamin Banneker HS           At-Risk      29               1
# 8     402  Benjamin Banneker HS             Black      78               1
# 9     402  Benjamin Banneker HS                EL  n < 10             NaN
# ..    ...                   ...               ...     ...             ...
# 225  DCPS     DC Public Schools      Multi-Racial      34        0.894737
# 226  DCPS     DC Public Schools        Non-binary  n < 10             NaN
# 227  DCPS     DC Public Schools  Pacific Islander  n < 10             NaN
# 228  DCPS     DC Public Schools               SWD     259        0.473492
# 229  DCPS     DC Public Schools             White     250        0.902527
#
#      YEAR
# 5    2019
# 6    2019
# 7    2019
# 8    2019
# 9    2019
# ..    ...
# 225  2021
# 226  2021
# 227  2021
# 228  2021
# 229  2021
#
# [426 rows x 6 columns]

# %%
joined_rates_total = joined_grad_rate[joined_grad_rate['ETHNICITY']=="All"]

# %%
joined_rates_total #MAKE THIS INTO A WIDE FORM DF
# Out:
#      CODE                                             SCHOOL ETHNICITY  \
# 5     402                               Benjamin Banneker HS       All
# 15    436          Ron Brown College Preparatory High School       All
# 19    442                         Columbia Heights EC (CHEC)       All
# 29    450                                       Anacostia HS       All
# 38    452                                          Ballou HS       All
# 46    454                                         Cardozo EC       All
# 56    455                                        Coolidge HS       All
